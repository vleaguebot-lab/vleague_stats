# %%
import time
import os
import re
import datetime
import glob

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score

# ディビジョンを日本語に
def div_ja(division):
    sex = '男子' if division[-1]=='m' else '女子'
    return 'V{0}{1}'.format(division[1], sex)

# %%
division = 'v1_w'
paths = glob.glob('../database/{}/teamdb_*'.format(division))
# paths = paths[-5:]
print(paths)
# Out:
# ['../database/v1_w\\teamdb_1999-00_regular.csv', '../database/v1_w\\teamdb_2000-01_regular.csv', '../database/v1_w\\teamdb_2001-02_regular.csv', '../database/v1_w\\teamdb_2002-03_regular.csv', '../database/v1_w\\teamdb_2003-04_regular.csv', '../database/v1_w\\teamdb_2004-05_regular.csv', '../database/v1_w\\teamdb_2005-06_regular.csv', '../database/v1_w\\teamdb_2006-07_regular.csv', '../database/v1_w\\teamdb_2007-08_regular.csv', '../database/v1_w\\teamdb_2008-09_regular.csv', '../database/v1_w\\teamdb_2009-10_regular.csv', '../database/v1_w\\teamdb_2010-11_regular.csv', '../database/v1_w\\teamdb_2011-12_regular.csv', '../database/v1_w\\teamdb_2012-13_regular.csv', '../database/v1_w\\teamdb_2013-14_regular.csv', '../database/v1_w\\teamdb_2014-15_regular.csv', '../database/v1_w\\teamdb_2015-16_regular.csv', '../database/v1_w\\teamdb_2016-17_regular.csv', '../database/v1_w\\teamdb_2017-18_regular.csv', '../database/v1_w\\teamdb_2018-19_regular.csv', '../database/v1_w\\teamdb_2019-20_regular.csv', '../database/v1_w\\teamdb_2020-21_regular.csv', '../database/v1_w\\teamdb_2021-22_regular.csv']

# %%
division = 'v2_m'
year = '2021-22_regular'
player_db_path =  '../database/{0}/playerdb_{1}.csv'.format(division,year)
team_db_path =  '../database/{0}/teamdb_{1}.csv'.format(division,year)
player_db = pd.read_csv(player_db_path)
team_db = pd.read_csv(team_db_path)
team_db.head()
# Out:
#     AA  AP  AE  ASucc%   AP/S  BAA  BAP  BAE  BASucc%  BP  ...  OpBP/S  OpSVA  \
# 0   98  42   9    42.9  14.00   10    2    2     20.0   8  ...    1.33     55
# 1  102  33   7    32.4  11.00   14    2    2     14.3   4  ...    2.67     74
# 2   81  37  11    45.7  12.33    9    6    2     66.7  11  ...    2.00     57
# 3   91  26  11    28.6   8.67   11    3    3     27.3   6  ...    3.67     74
# 4   71  41   5    57.7  13.67   20   13    0     65.0  11  ...    1.00     50
#
#    OpSVP  OpSVE  OpSVx  OpSVEff%  OpRA  OpRx  OpRg  OpRSucc%
# 0      1     10      5      -0.5    67  30.0  23.0      61.9
# 1      4      5     12       7.8    45  25.0  14.0      71.1
# 2      2     11     18       6.6    64  24.0  20.0      53.1
# 3      3      8     20       8.1    46  12.0  14.0      41.3
# 4      1      9      6       0.5    65  28.0  20.0      58.5
#
# [5 rows x 66 columns]

# %%
team_db.columns
# Out:
# Index(['AA', 'AP', 'AE', 'ASucc%', 'AP/S', 'BAA', 'BAP', 'BAE', 'BASucc%',
#        'BP', 'BP/S', 'SVA', 'SVP', 'SVE', 'SVx', 'SVEff%', 'RA', 'Rx', 'Rg',
#        'RSucc%', 'MatchNo.', 'Date', 'Year', 'Month', 'Day', 'Place', 'Venue',
#        'Team', 'Op.Team', 'Director', 'Coach', 'Win_Set', 'Lose_Set',
#        'Total_Set', 'Win_Lose', 'Get_Point', 'Lose_Point', 'Game_Time',
#        'Start_Time', 'End_Time', 'Spectators', 'Jury', 'Chief_Umpire',
#        'Sub_Umpire', 'Judgeman', 'Home_Away', 'OpAA', 'OpAP', 'OpAE',
#        'OpASucc%', 'OpAP/S', 'OpBAA', 'OpBAP', 'OpBAE', 'OpBASucc%', 'OpBP',
#        'OpBP/S', 'OpSVA', 'OpSVP', 'OpSVE', 'OpSVx', 'OpSVEff%', 'OpRA',
#        'OpRx', 'OpRg', 'OpRSucc%'],
#       dtype='object')

# %%
team_db_total = team_db.groupby('Team').sum()
team_db_total[['Win_Set', 'Lose_Set']]
# Out:
#                   Win_Set  Lose_Set
# Team
# きんでんトリニティーブリッツ         43        58
# つくばユナイテッドSunGAIA       48        51
# クボタスピアーズ               32        54
# サフィルヴァ北海道              47        55
# トヨタ自動車サンホークス           41        31
# ヴィアティン三重               71        25
# ヴォレアス北海道               74        16
# 兵庫デルフィーノ               39        53
# 千葉ZELVA                22        70
# 埼玉アザレア                 59        37
# 大同特殊鋼レッドスター            50        49
# 奈良ドリーマーズ               39        63
# 富士通カワサキレッドスピリッツ        74        17
# 東京ヴェルディ                27        68
# 警視庁フォートファイターズ          40        59

# %%
team_db['Set'] = team_db['Win_Set'] + team_db['Lose_Set']

# %%
def stats_calc(df):
    df['Set'] = df['Win_Set'] + df['Lose_Set']
    df['ASucc%'] = ((df['AP'] / df['AA']) * 100).round(1)
    df['AEff%'] = (((df['AP']-df['AE']) /
                     df['AA']) * 100).round(1)
    df['BASucc%'] = ((df['BAP'] / df['BAA']) * 100).round(1)
    df['AP/S'] = (df['AP'] / df['Set']).round(2)
    df['BP/S'] = (df['BP'] / df['Set']).round(2)
    df['SVEff%'] = ((df['SVP'] * 100 + df['SVx'] * 25 -
                    df['SVE'] * 25) / df['SVA']).round(1)
    df['RSucc%'] = (
        (df['Rx'] * 100 + df['Rg'] * 50) / df['RA']).round(1)
    return df

# %%
team_db_total = stats_calc(team_db_total)
team_db_total
# Out:
#                     AA    AP   AE  ASucc%   AP/S  BAA  BAP  BAE  BASucc%   BP  \
# Team
# きんでんトリニティーブリッツ    2881  1329  272    46.1  13.16  523  247   82     47.2  194
# つくばユナイテッドSunGAIA  2919  1289  223    44.2  13.02  540  218   75     40.4  209
# クボタスピアーズ          2517  1045  217    41.5  12.15  402  184   54     45.8  175
# サフィルヴァ北海道         2903  1275  266    43.9  12.50  585  249   86     42.6  249
# トヨタ自動車サンホークス      2061   907  188    44.0  12.60  198   93   34     47.0  151
# ヴィアティン三重          2764  1339  194    48.4  13.95  438  209   58     47.7  215
# ヴォレアス北海道          2354  1221  186    51.9  13.57  526  277   68     52.7  261
# 兵庫デルフィーノ          2766  1126  246    40.7  12.24  426  149   53     35.0  210
# 千葉ZELVA           2647  1083  218    40.9  11.77  474  179   76     37.8  167
# 埼玉アザレア            2828  1275  185    45.1  13.28  439  174   51     39.6  261
# 大同特殊鋼レッドスター       2875  1303  229    45.3  13.16  372  157   64     42.2  193
# 奈良ドリーマーズ          2921  1274  231    43.6  12.49  513  228   70     44.4  180
# 富士通カワサキレッドスピリッツ   2458  1343  196    54.6  14.76  452  236   64     52.2  195
# 東京ヴェルディ           2759  1184  270    42.9  12.46  485  192   77     39.6  147
# 警視庁フォートファイターズ     2935  1296  271    44.2  13.09  447  148   73     33.1  219
#
#                   ...  OpSVP  OpSVE  OpSVx  OpSVEff%  OpRA   OpRx   OpRg  \
# Team              ...
# きんでんトリニティーブリッツ    ...     90    330    510     152.8  1817  825.0  504.0
# つくばユナイテッドSunGAIA  ...     68    340    405      97.1  1860  912.0  461.0
# クボタスピアーズ          ...     71    283    405     115.9  1546  748.0  364.0
# サフィルヴァ北海道         ...    100    315    549     170.4  1819  813.0  534.0
# トヨタ自動車サンホークス      ...     65    231    285      90.7  1408  642.0  435.0
# ヴィアティン三重          ...     53    298    311      69.2  1912  879.0  542.0
# ヴォレアス北海道          ...     63    292    329     100.1  1789  780.0  438.0
# 兵庫デルフィーノ          ...     65    295    351      90.3  1619  743.0  453.0
# 千葉ZELVA           ...    104    292    431     158.0  1623  870.0  446.0
# 埼玉アザレア            ...     55    285    428     106.6  1986  937.0  545.0
# 大同特殊鋼レッドスター       ...     60    299    492     121.7  1948  872.0  565.0
# 奈良ドリーマーズ          ...     99    321    494     169.9  1783  813.0  456.0
# 富士通カワサキレッドスピリッツ   ...     73    288    363     112.5  1773  747.0  461.0
# 東京ヴェルディ           ...     94    285    504     173.1  1627  865.0  382.0
# 警視庁フォートファイターズ     ...     74    264    421     126.5  1842  851.0  547.0
#
#                   OpRSucc%  Set  AEff%
# Team
# きんでんトリニティーブリッツ      1539.3  101   36.7
# つくばユナイテッドSunGAIA    1536.2   99   36.5
# クボタスピアーズ            1337.4   86   32.9
# サフィルヴァ北海道           1491.4  102   34.8
# トヨタ自動車サンホークス        1205.9   72   34.9
# ヴィアティン三重            1561.2   96   41.4
# ヴォレアス北海道            1394.5   90   44.0
# 兵庫デルフィーノ            1381.7   92   31.8
# 千葉ZELVA             1685.4   92   32.7
# 埼玉アザレア              1527.8   96   38.5
# 大同特殊鋼レッドスター         1499.5   99   37.4
# 奈良ドリーマーズ            1575.4  102   35.7
# 富士通カワサキレッドスピリッツ     1429.5   91   46.7
# 東京ヴェルディ             1622.6   95   33.1
# 警視庁フォートファイターズ       1527.3   99   34.9
#
# [15 rows x 53 columns]

# %%
team_db_main = team_db_total[['ASucc%', 'BASucc%', 'BP/S', 'SVEff%', 'RSucc%']]
team_db_main
# Out:
#                   ASucc%  BASucc%  BP/S  SVEff%  RSucc%
# Team
# きんでんトリニティーブリッツ      46.1     47.2  1.92     4.7    55.4
# つくばユナイテッドSunGAIA    44.2     40.4  2.11     3.6    64.0
# クボタスピアーズ            41.5     45.8  2.03     4.6    61.6
# サフィルヴァ北海道           43.9     42.6  2.44     4.1    53.5
# トヨタ自動車サンホークス        44.0     47.0  2.10     5.0    59.9
# ヴィアティン三重            48.4     47.7  2.24     6.1    66.5
# ヴォレアス北海道            51.9     52.7  2.90     8.0    63.3
# 兵庫デルフィーノ            40.7     35.0  2.28     4.6    65.1
# 千葉ZELVA             40.9     37.8  1.82     3.3    59.3
# 埼玉アザレア              45.1     39.6  2.72     6.3    61.3
# 大同特殊鋼レッドスター         45.3     42.2  1.95     6.1    56.8
# 奈良ドリーマーズ            43.6     44.4  1.76     4.7    58.1
# 富士通カワサキレッドスピリッツ     54.6     52.2  2.14     6.4    59.6
# 東京ヴェルディ             42.9     39.6  1.55     3.9    57.9
# 警視庁フォートファイターズ       44.2     33.1  2.21     4.9    62.9

# %%
index=[
    "ヴォレアス北海道","富士通カワサキレッドスピリッツ","ヴィアティン三重", 
    "埼玉アザレア","サフィルヴァ北海道","大同特殊鋼レッドスター",
    "兵庫デルフィーノ","きんでんトリニティーブリッツ","つくばユナイテッドSunGAIA",
    "トヨタ自動車サンホークス","奈良ドリーマーズ","警視庁フォートファイターズ",
    "東京ヴェルディ","クボタスピアーズ","千葉ZELVA"
]
team_db_main_std = team_db_main.apply(lambda x: (x-x.mean())/x.std()).reindex()
team_db_main_std
# Out:
#                     ASucc%   BASucc%      BP/S    SVEff%    RSucc%
# Team
# きんでんトリニティーブリッツ    0.244605  0.703189 -0.638715 -0.306115 -1.348679
# つくばユナイテッドSunGAIA -0.246327 -0.478447 -0.098555 -1.176961  0.996059
# クボタスピアーズ         -0.943967  0.459911 -0.325991 -0.385283  0.341714
# サフィルヴァ北海道        -0.323843 -0.096153  0.839616 -0.781122 -1.866702
# トヨタ自動車サンホークス     -0.298004  0.668435 -0.126985 -0.068612 -0.121781
# ヴィアティン三重          0.838890  0.790074  0.271027  0.802233  1.677669
# ヴォレアス北海道          1.743239  1.658924  2.147371  2.306421  0.805208
# 兵庫デルフィーノ         -1.150675 -1.416805  0.384745 -0.385283  1.295967
# 千葉ZELVA          -1.098998 -0.930249 -0.923009 -1.414464 -0.285367
# 埼玉アザレア           -0.013781 -0.617463  1.635641  0.960569  0.259921
# 大同特殊鋼レッドスター       0.037896 -0.165661 -0.553426  0.802233 -0.966977
# 奈良ドリーマーズ         -0.401358  0.216633 -1.093586 -0.306115 -0.612540
# 富士通カワサキレッドスピリッツ   2.440878  1.572039 -0.013267  1.039737 -0.203574
# 東京ヴェルディ          -0.582228 -0.617463 -1.690604 -0.939457 -0.667069
# 警視庁フォートファイターズ    -0.246327 -1.746968  0.185739 -0.147780  0.696151

# %%
plt.figure(figsize=(9,7.5))
# sns.set(font_scale=2)
sns.heatmap(team_db_main_std, annot=True, cmap='bwr',vmax=2, vmin=-2)
plt.savefig('test.png', facecolor='white',bbox_inches="tight")
plt.show()
